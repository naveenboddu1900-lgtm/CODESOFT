# %% [markdown]
# <a href="https://colab.research.google.com/github/naveenboddu1900-lgtm/CODESOFT/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("loan_prediction.csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.isnull().sum()

# Fill categorical with mode
for col in df.select_dtypes(include='object'):
    df[col] = df[col].fillna(df[col].mode()[0])

# Fill numerical with median
for col in df.select_dtypes(include=np.number):
    df[col] = df[col].fillna(df[col].median())

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.select_dtypes(include='object'):
    df[col] = le.fit_transform(df[col])

# %%
X = df.drop('Loan_Status', axis=1)
y = df['Loan_Status']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_scaled, y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_res, y_res, test_size=0.2, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score

lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)
y_prob_lr = lr.predict_proba(X_test)[:,1]

print("Logistic Regression")
print(classification_report(y_test, y_pred_lr))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_lr))
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        94
#            1       0.59      0.92      0.72        75
#
#     accuracy                           0.69       169
#    macro avg       0.74      0.71      0.68       169
# weighted avg       0.76      0.69      0.68       169
#
# ROC-AUC: 0.721418439716312

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, roc_auc_score

lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)
y_prob_lr = lr.predict_proba(X_test)[:,1]

print("Logistic Regression")
print(classification_report(y_test, y_pred_lr))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_lr))
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        94
#            1       0.59      0.92      0.72        75
#
#     accuracy                           0.69       169
#    macro avg       0.74      0.71      0.68       169
# weighted avg       0.76      0.69      0.68       169
#
# ROC-AUC: 0.721418439716312

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)
y_prob_rf = rf.predict_proba(X_test)[:,1]

print("Random Forest")
print(classification_report(y_test, y_pred_rf))
print("ROC-AUC:", roc_auc_score(y_test, y_prob_rf))
# Out:
# Random Forest
#               precision    recall  f1-score   support
#
#            0       0.89      0.70      0.79        94
#            1       0.71      0.89      0.79        75
#
#     accuracy                           0.79       169
#    macro avg       0.80      0.80      0.79       169
# weighted avg       0.81      0.79      0.79       169
#
# ROC-AUC: 0.8760283687943262

# %%
results = {
    "Model": ["Logistic Regression", "Random Forest"],
    "ROC-AUC": [
        roc_auc_score(y_test, y_prob_lr),
        roc_auc_score(y_test, y_prob_rf)
    ]
}

pd.DataFrame(results)
# Out:
#                  Model   ROC-AUC
# 0  Logistic Regression  0.721418
# 1        Random Forest  0.876028

# %%
import numpy as np

threshold = 0.4  # try lower threshold for higher recall

y_custom = (y_prob_rf >= threshold).astype(int)

print("Custom Threshold Report")
print(classification_report(y_test, y_custom))
# Out:
# Custom Threshold Report
#               precision    recall  f1-score   support
#
#            0       0.94      0.65      0.77        94
#            1       0.68      0.95      0.79        75
#
#     accuracy                           0.78       169
#    macro avg       0.81      0.80      0.78       169
# weighted avg       0.82      0.78      0.78       169
